# %%
from sklearn.datasets import make_blobs
#make blobs is used for generating synthetic data generator , used to generate usefull data for clustering , classification algorithms

# %%
import pandas as  pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#creating datasets 

#creating the normal datasets 
X_normal , y_normal = make_blobs(n_samples = 500 , centers = 3 )

# %%
fig,  (ax1 , ax2)  = plt.subplots(1 , 2 , figsize = (12 , 5 ))

# %%
plt.hist(X_normal.ravel() , bins = int((len(y_normal) * ((30 * 100 / (len(X_normal.ravel())) )))/100 )  , color = 'red'  , alpha = 0.6)
plt.show()

# %%
plt.hist(X_normal.ravel() , bins = 30 )
# Out:
# (array([ 1.,  1.,  7., 12., 35., 56., 58., 76., 82., 66., 71., 70., 62.,
#         46., 27., 36., 34., 43., 22., 23.,  5.,  3.,  8., 19., 33., 30.,
#         36., 24., 11.,  3.]),
#  array([-8.88698579, -8.29703952, -7.70709326, -7.11714699, -6.52720072,
#         -5.93725446, -5.34730819, -4.75736192, -4.16741566, -3.57746939,
#         -2.98752312, -2.39757686, -1.80763059, -1.21768432, -0.62773806,
#         -0.03779179,  0.55215448,  1.14210074,  1.73204701,  2.32199328,
#          2.91193954,  3.50188581,  4.09183208,  4.68177834,  5.27172461,
#          5.86167088,  6.45161714,  7.04156341,  7.63150968,  8.22145594,
#          8.81140221]),
#  <BarContainer object of 30 artists>)

# %%
# Out:
# 500

# %%
# Out:
# 15.0

# %%
plt.scatter(X_normal[: , 0]  , X_normal[: , 1 ])

# %%
\
